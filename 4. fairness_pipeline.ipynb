# %%
# %matplotlib inline
from tkinter import *

import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import ConfusionMatrixDisplay

from utils.fairness_functions import *

# %% [markdown]
# # Global variables

# %%
protected_attribute = "applicant_race_1"
unpriviledged_num = 0.682999
privileged_num = -0.145577
iRandom = 123
iDepth = None
n_estimators = 688

# %% [markdown]
# # Data import

# %%
df = pd.read_csv("./data/woe_df.csv")

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ### Discriminative logistic regression

# %%
LogReg_output = Estfun_ML(
    "Logistic Regression",
    df,
    iDepth,
    iRandom,
    protected_attribute,
    unpriviledged_num,
    privileged_num,
    None,
    True,
)
# Out:
# Logistic Regression algorithm succesfully recognized.
# Estimating the Logistic Regression model
# training a ML model
# .
# .

# %%
print(LogReg_output[4])
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.64      0.74    143060
#            1       0.33      0.69      0.45     36940
#
#     accuracy                           0.65    180000
#    macro avg       0.61      0.66      0.60    180000
# weighted avg       0.77      0.65      0.68    180000

# %%
dfM_LogReg_output = LogReg_output[7]
Performance_LogReg_output = LogReg_output[8]
auc_train_LogReg_output, auc_test_LogReg_output = LogReg_output[9], LogReg_output[10]

# %% [markdown]
# ### Fair logistic regression

# %%
LogReg_outputWO = Estfun_ML(
    "Logistic Regression",
    df,
    iDepth,
    iRandom,
    protected_attribute,
    unpriviledged_num,
    privileged_num,
    None,
    False,
)
# Out:
# Logistic Regression algorithm succesfully recognized.
# Estimating the Logistic Regression model
# training a ML model
# .
# .

# %%
print("Confusion Matrix Report")
print(LogReg_outputWO[4])
# Out:
# Confusion Matrix Report
#               precision    recall  f1-score   support
#
#            0       0.89      0.65      0.75    143060
#            1       0.33      0.68      0.44     36940
#
#     accuracy                           0.65    180000
#    macro avg       0.61      0.66      0.60    180000
# weighted avg       0.77      0.65      0.69    180000

# %%
dfM_LogReg_outputWO = LogReg_outputWO[7]
Performance_LogReg_outputWO = LogReg_outputWO[8]
auc_train_LogReg_outputWO, auc_test_LogReg_outputWO = (
    LogReg_outputWO[9],
    LogReg_outputWO[10],
)

# %% [markdown]
# ### LR Pre-processing: Disparate Impact Remover

# %%
LogReg_outputDIWO = Estfun_ML(
    "Logistic Regression",
    df,
    iDepth,
    iRandom,
    protected_attribute,
    unpriviledged_num,
    privileged_num,
    "DisparateImpactRemover",
    False,
)
# Out:
# Logistic Regression algorithm succesfully recognized.
# Estimating the Logistic Regression model
# training a ML model
# Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
# Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
# .
# .
# Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.

# %%
print("Confusion Matrix Report")
print(LogReg_outputDIWO[4])
# Out:
# Confusion Matrix Report
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.64      0.74    143060
#          1.0       0.33      0.68      0.44     36940
#
#     accuracy                           0.65    180000
#    macro avg       0.61      0.66      0.59    180000
# weighted avg       0.77      0.65      0.68    180000

# %%
dfM_LogReg_outputDIWO = LogReg_outputDIWO[7]
Performance_LogReg_outputDIWO = LogReg_outputDIWO[8]
auc_train_LogReg_outputDIWO, auc_test_LogReg_outputDIWO = (
    LogReg_outputDIWO[9],
    LogReg_outputDIWO[10],
)

# %% [markdown]
# ### LR Pre-processing: Reweighting

# %%
# %matplotlib inline

# %%
LogReg_outputRWWO = Estfun_ML(
    "Logistic Regression",
    df,
    iDepth,
    iRandom,
    protected_attribute,
    unpriviledged_num,
    privileged_num,
    "Reweighting",
    False,
)
# Out:
# Logistic Regression algorithm succesfully recognized.
# Estimating the Logistic Regression model
# training a weighted model
# .
# .

# %%
print("Confusion Matrix Report")
print(LogReg_outputRWWO[4])
# Out:
# Confusion Matrix Report
#               precision    recall  f1-score   support
#
#            0       0.88      0.65      0.75    143060
#            1       0.33      0.67      0.45     36940
#
#     accuracy                           0.66    180000
#    macro avg       0.61      0.66      0.60    180000
# weighted avg       0.77      0.66      0.69    180000

# %%
dfM_LogReg_outputRWWO = LogReg_outputRWWO[7]
Performance_LogReg_outputRWWO = LogReg_outputRWWO[8]
auc_train_LogReg_outputRWWO, auc_test_LogReg_outputRWWO = (
    LogReg_outputRWWO[9],
    LogReg_outputRWWO[10],
)

# %% [markdown]
# ### LR Post-processing: Equalized Odds

# %%
LogReg_outputEOWO = Estfun_ML(
    "Logistic Regression",
    df,
    iDepth,
    iRandom,
    protected_attribute,
    unpriviledged_num,
    privileged_num,
    "EqualizedOds",
    False,
)
# Out:
# Logistic Regression algorithm succesfully recognized.
# Estimating the Logistic Regression model
# training a ML model
#  Found a True value for the following postprocessing technique: EqualizedOds
#  Adjusting the data set accordingly.
# .
# .
# .
# .

# %%
print("Confusion Matrix Report")
print(LogReg_outputEOWO[4])
# Out:
# Confusion Matrix Report
#               precision    recall  f1-score   support
#
#            0       0.85      0.69      0.76    143060
#            1       0.30      0.52      0.38     36940
#
#     accuracy                           0.65    180000
#    macro avg       0.57      0.60      0.57    180000
# weighted avg       0.73      0.65      0.68    180000

# %%
dfM_LogReg_outputEOWO = LogReg_outputEOWO[7]
Performance_LogReg_outputEOWO = LogReg_outputEOWO[8]
auc_train_LogReg_outputEOWO, auc_test_LogReg_outputEOWO = (
    LogReg_outputEOWO[9],
    LogReg_outputEOWO[10],
)

# %% [markdown]
# ### LR Post-processing: Reject Option Classification

# %%
LogReg_outputROCWO = Estfun_ML(
    "Logistic Regression",
    df,
    iDepth,
    iRandom,
    protected_attribute,
    unpriviledged_num,
    privileged_num,
    "RejectOptionClassification",
    False,
)
# Out:
# Logistic Regression algorithm succesfully recognized.
# Estimating the Logistic Regression model
# training a ML model
#  Found a True value for the following postprocessing technique: RejectOptionClassification
#  Adjusting the data set accordingly.
# .
# .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19124\2962542288.py in <module>
#       8     privileged_num,
#       9     "RejectOptionClassification",
# ---> 10     False,
#      11 )
#
# c:\Users\FI40WR\OneDrive - ING\Desktop\Internship\SGH-master-dissertation\utils\fairness_functions.py in Estfun_ML(sFun_ML, dfX, iDepth, iRandom, protected_attribute_name, unprivileged_num, privileged_num, sFairnessMetric, IncludeProtected)
#    1117                 privileged_num,
#    1118                 unprivileged_num,
# -> 1119                 sFairnessMetric,
#    1120             )
#    1121
#
# c:\Users\FI40WR\OneDrive - ING\Desktop\Internship\SGH-master-dissertation\utils\fairness_functions.py in AdjustPostprocessing(dfX, dfY, target, protected_attribute_name, privileged_num, unprivileged_num, sFairnessMetric)
#     352             num_class_thresh=100,
#     353             num_ROC_margin=50,
# --> 354         ).fit_predict(BinLabel_true, BinLabel_predicted)
#     355         dfAdjusted = ROC.convert_to_dataframe()[0]
#     356
#
# c:\Users\FI40WR\Anaconda3\envs\model_fairness\lib\site-packages\aif360\algorithms\transformer.py in wrapper(self, *args, **kwargs)
#      25     @wraps(func)
#      26     def wrapper(self, *args, **kwargs):
# ---> 27         new_dataset = func(self, *args, **kwargs)
#      28         if isinstance(new_dataset, Dataset):
#      29             new_dataset.metadata = new_dataset.metadata.copy()
#
# c:\Users\FI40WR\Anaconda3\envs\model_fairness\lib\site-packages\aif360\algorithms\postprocessing\reject_option_classification.py in fit_predict(self, dataset_true, dataset_pred)
#     214     def fit_predict(self, dataset_true, dataset_pred):
#     215         """fit and predict methods sequentially."""
# --> 216         return self.fit(dataset_true, dataset_pred).predict(dataset_pred)
#     217
#     218 # Function to obtain the pareto frontier
#
# c:\Users\FI40WR\Anaconda3\envs\model_fairness\lib\site-packages\aif360\algorithms\transformer.py in wrapper(self, *args, **kwargs)
#      25     @wraps(func)
#      26     def wrapper(self, *args, **kwargs):
# ---> 27         new_dataset = func(self, *args, **kwargs)
#      28         if isinstance(new_dataset, Dataset):
#      29             new_dataset.metadata = new_dataset.metadata.copy()
#
# c:\Users\FI40WR\Anaconda3\envs\model_fairness\lib\site-packages\aif360\algorithms\postprocessing\reject_option_classification.py in fit(self, dataset_true, dataset_pred)
#     135                                              dataset_transf_pred,
#     136                                              unprivileged_groups=self.unprivileged_groups,
# --> 137                                              privileged_groups=self.privileged_groups)
#     138
#     139                 ROC_margin_arr[cnt] = self.ROC_margin
#
# c:\Users\FI40WR\Anaconda3\envs\model_fairness\lib\site-packages\aif360\metrics\classification_metric.py in __init__(self, dataset, classified_dataset, unprivileged_groups, privileged_groups)
#      64         # for the two datasets
#      65         with self.dataset.temporarily_ignore('labels', 'scores'):
# ---> 66             if self.dataset != self.classified_dataset:
#      67                 raise ValueError("The two datasets are expected to differ only "
#      68                                  "in 'labels' or 'scores'.")
#
# c:\Users\FI40WR\Anaconda3\envs\model_fairness\lib\site-packages\aif360\datasets\structured_dataset.py in __ne__(self, other)
#     190
#     191     def __ne__(self, other):
# --> 192         return not self == other
#     193
#     194     def __repr__(self):
#
# c:\Users\FI40WR\Anaconda3\envs\model_fairness\lib\site-packages\aif360\datasets\structured_dataset.py in __eq__(self, other)
#     187
#     188         return all(_eq(self.__dict__[k], other.__dict__[k])
# --> 189                    for k in self.__dict__.keys() if k not in self.ignore_fields)
#     190
#     191     def __ne__(self, other):
#
# c:\Users\FI40WR\Anaconda3\envs\model_fairness\lib\site-packages\aif360\datasets\structured_dataset.py in <genexpr>(.0)
#     187
#     188         return all(_eq(self.__dict__[k], other.__dict__[k])
# --> 189                    for k in self.__dict__.keys() if k not in self.ignore_fields)
#     190
#     191     def __ne__(self, other):
#
# c:\Users\FI40WR\Anaconda3\envs\model_fairness\lib\site-packages\aif360\datasets\structured_dataset.py in _eq(x, y)
#     183                 return np.all(x == y)
#     184             elif isinstance(x, list) and isinstance(y, list):
# --> 185                 return len(x) == len(y) and all(_eq(xi, yi) for xi, yi in zip(x, y))
#     186             return x == y
#     187
#
# c:\Users\FI40WR\Anaconda3\envs\model_fairness\lib\site-packages\aif360\datasets\structured_dataset.py in <genexpr>(.0)
#     183                 return np.all(x == y)
#     184             elif isinstance(x, list) and isinstance(y, list):
# --> 185                 return len(x) == len(y) and all(_eq(xi, yi) for xi, yi in zip(x, y))
#     186             return x == y
#     187
#
# KeyboardInterrupt:

# %%
print("Confusion Matrix Report")
print(LogReg_outputROCWO[4])
# Out:
# Confusion Matrix Report
#               precision    recall  f1-score   support
#
#            0       0.89      0.65      0.75    143060
#            1       0.33      0.68      0.44     36940
#
#     accuracy                           0.65    180000
#    macro avg       0.61      0.66      0.60    180000
# weighted avg       0.77      0.65      0.69    180000

# %%
dfM_LogReg_outputROCWO = LogReg_outputROCWO[7]
Performance_LogReg_outputROCWO = LogReg_outputROCWO[8]
auc_train_LogReg_outputROCWO, auc_test_LogReg_outputROCWO = (
    LogReg_outputROCWO[9],
    LogReg_outputROCWO[10],
)

# %% [markdown]
# # Random Forest

# %% [markdown]
# ### Discriminative Random Forest

# %%
RandomForest_output = Estfun_ML(
    "Random Forest",
    df,
    iDepth,
    iRandom,
    protected_attribute,
    unpriviledged_num,
    privileged_num,
    None,
    True,
)
# Out:
# Random Forest algorithm succesfully recognized.
# Estimating the Random Forest model
# training a ML model
# .
# .

# %%
print("Confusion Matrix Report")
print(RandomForest_output[4])
# Out:
# Confusion Matrix Report
#               precision    recall  f1-score   support
#
#            0       0.88      0.71      0.79    143060
#            1       0.35      0.61      0.45     36940
#
#     accuracy                           0.69    180000
#    macro avg       0.62      0.66      0.62    180000
# weighted avg       0.77      0.69      0.72    180000

# %%
dfM_RandomForest_output = RandomForest_output[7]
Performance_RandomForest_output = RandomForest_output[8]
auc_train_RandomForest_output, auc_test_RandomForest_output = (
    RandomForest_output[9],
    RandomForest_output[10],
)

# %% [markdown]
# ### Fair Random Forest

# %%
RandomForest_outputWO = Estfun_ML(
    "Random Forest",
    df,
    iDepth,
    iRandom,
    protected_attribute,
    unpriviledged_num,
    privileged_num,
    None,
    False,
)
# Out:
# Random Forest algorithm succesfully recognized.
# Estimating the Random Forest model
# training a ML model
# .
# .

# %%
print("Confusion Matrix Report")
print(RandomForest_outputWO[4])
# Out:
# Confusion Matrix Report
#               precision    recall  f1-score   support
#
#            0       0.88      0.69      0.78    143060
#            1       0.35      0.63      0.45     36940
#
#     accuracy                           0.68    180000
#    macro avg       0.61      0.66      0.61    180000
# weighted avg       0.77      0.68      0.71    180000

# %%
dfM_RandomForest_outputWO = RandomForest_outputWO[7]
Performance_RandomForest_outputWO = RandomForest_outputWO[8]
auc_train_RandomForest_outputWO, auc_test_RandomForest_outputWO = (
    RandomForest_outputWO[9],
    RandomForest_outputWO[10],
)

# %% [markdown]
# ### Random Forest Pre-processing: Disparate Impact Remover

# %%
RandomForest_outputDIWO = Estfun_ML(
    "Random Forest",
    df,
    iDepth,
    iRandom,
    protected_attribute,
    unpriviledged_num,
    privileged_num,
    "DisparateImpactRemover",
    False,
)
# Out:
# Random Forest algorithm succesfully recognized.
# Estimating the Random Forest model
# training a ML model
# Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
# Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
# Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
# .
# .
# Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.

# %%
print("Confusion Matrix Report")
print(RandomForest_outputDIWO[4])
# Out:
# Confusion Matrix Report
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.69      0.77    143060
#          1.0       0.35      0.64      0.45     36940
#
#     accuracy                           0.68    180000
#    macro avg       0.61      0.66      0.61    180000
# weighted avg       0.77      0.68      0.71    180000

# %%
dfM_RandomForest_outputDIWO = RandomForest_outputDIWO[7]
Performance_RandomForest_outputDIWO = RandomForest_outputDIWO[8]
auc_train_RandomForest_outputDIWO, auc_test_RandomForest_outputDIWO = (
    RandomForest_outputDIWO[9],
    RandomForest_outputDIWO[10],
)

# %% [markdown]
# ### Random Forest Pre-processing: Reweighting

# %%
RandomForest_outputRWWO = Estfun_ML(
    "Random Forest",
    df,
    iDepth,
    iRandom,
    protected_attribute,
    unpriviledged_num,
    privileged_num,
    "Reweighting",
    False,
)
# Out:
# Random Forest algorithm succesfully recognized.
# Estimating the Random Forest model
# training a weighted model
# .
# .

# %%
print("Confusion Matrix Report")
print(RandomForest_outputRWWO[4])
# Out:
# Confusion Matrix Report
#               precision    recall  f1-score   support
#
#            0       0.88      0.71      0.78    143060
#            1       0.35      0.62      0.45     36940
#
#     accuracy                           0.69    180000
#    macro avg       0.61      0.66      0.61    180000
# weighted avg       0.77      0.69      0.71    180000

# %%
dfM_RandomForest_outputRWWO = RandomForest_outputRWWO[7]
Performance_RandomForest_outputRWWO = RandomForest_outputRWWO[8]
auc_train_RandomForest_outputRWWO, auc_test_RandomForest_outputRWWO = (
    RandomForest_outputRWWO[9],
    RandomForest_outputRWWO[10],
)

# %% [markdown]
# ### Random Forest Post-processing: Equalized Odds

# %%
RandomForest_outputEOWO = Estfun_ML(
    "Random Forest",
    df,
    iDepth,
    iRandom,
    protected_attribute,
    unpriviledged_num,
    privileged_num,
    "EqualizedOds",
    False,
)
# Out:
# Random Forest algorithm succesfully recognized.
# Estimating the Random Forest model
#  Found a True value for the following postprocessing technique: EqualizedOds
#  Adjusting the data set accordingly.
# .
# .
# .
# .

# %%
print("Confusion Matrix Report")
print(RandomForest_outputEOWO[4])
# Out:
# Confusion Matrix Report
#               precision    recall  f1-score   support
#
#            0       0.85      0.75      0.79    143060
#            1       0.33      0.47      0.39     36940
#
#     accuracy                           0.69    180000
#    macro avg       0.59      0.61      0.59    180000
# weighted avg       0.74      0.69      0.71    180000

# %%
dfM_RandomForest_outputEOWO = RandomForest_outputEOWO[7]
Performance_RandomForest_outputEOWO = RandomForest_outputEOWO[8]
auc_train_RandomForest_outputEOWO, auc_test_RandomForest_outputEOWO = (
    RandomForest_outputEOWO[9],
    RandomForest_outputEOWO[10],
)

# %% [markdown]
# ### Random Forest Post-processing: Reject Option Classification

# %%
RandomForest_outputROCWO = Estfun_ML(
    "Random Forest",
    df,
    iDepth,
    iRandom,
    protected_attribute,
    unpriviledged_num,
    privileged_num,
    "RejectOptionClassification",
    False,
)
# Out:
# Random Forest algorithm succesfully recognized.
# Estimating the Random Forest model
#  Found a True value for the following postprocessing technique: RejectOptionClassification
#  Adjusting the data set accordingly.
# .
# .
# Unable to satisy fairness constraints
# .
# .

# %%
print("Confusion Matrix Report")
print(RandomForest_outputROCWO[4])
# Out:
# Confusion Matrix Report
#               precision    recall  f1-score   support
#
#            0       0.88      0.69      0.78    143060
#            1       0.35      0.63      0.45     36940
#
#     accuracy                           0.68    180000
#    macro avg       0.61      0.66      0.61    180000
# weighted avg       0.77      0.68      0.71    180000

# %%
dfM_RandomForest_outputROCWO = RandomForest_outputROCWO[7]
Performance_RandomForest_outputROCWO = RandomForest_outputROCWO[8]
auc_train_RandomForest_outputROCWO, auc_test_RandomForest_outputROCWO = (
    RandomForest_outputROCWO[9],
    RandomForest_outputROCWO[10],
)

# %% [markdown]
# # Extreme gradient boosting

# %% [markdown]
# ### Discriminative XGBoost

# %%
GB_output = Estfun_ML(
    "XGBoost",
    df,
    iDepth,
    iRandom,
    protected_attribute,
    unpriviledged_num,
    privileged_num,
    None,
    True,
)
# Out:
# XGBoost algorithm succesfully recognized.
# Estimating the XGBoost model
# [13:49:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "max_features" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# .
# .

# %%
print("Confusion Matrix Report")
print(GB_output[4])
# Out:
# Confusion Matrix Report
#               precision    recall  f1-score   support
#
#            0       0.88      0.71      0.79    143060
#            1       0.36      0.64      0.46     36940
#
#     accuracy                           0.69    180000
#    macro avg       0.62      0.67      0.62    180000
# weighted avg       0.78      0.69      0.72    180000

# %%
dfM_GB_output = GB_output[7]
Performance_GB_output = GB_output[8]
auc_train_GB_output, auc_test_GB_output = GB_output[9], GB_output[10]

# %% [markdown]
# ### Fair XGBoost

# %%
GB_outputWO = Estfun_ML(
    "XGBoost",
    df,
    iDepth,
    iRandom,
    protected_attribute,
    unpriviledged_num,
    privileged_num,
    None,
    False,
)
# Out:
# XGBoost algorithm succesfully recognized.
# Estimating the XGBoost model
# [13:49:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "max_features" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# .
# .

# %%
print("Confusion Matrix Report")
print(GB_outputWO[4])
# Out:
# Confusion Matrix Report
#               precision    recall  f1-score   support
#
#            0       0.88      0.69      0.78    143060
#            1       0.35      0.65      0.46     36940
#
#     accuracy                           0.68    180000
#    macro avg       0.62      0.67      0.62    180000
# weighted avg       0.77      0.68      0.71    180000

# %%
dfM_GB_outputWO = GB_outputWO[7]
Performance_GB_outputWO = GB_outputWO[8]
auc_train_GB_outputWO, auc_test_GB_outputWO = GB_outputWO[9], GB_outputWO[10]

# %% [markdown]
# ### XGBoost Pre-processing: Disparate Impact Remover

# %%
GB_outputDIWO = Estfun_ML(
    "XGBoost",
    df,
    iDepth,
    iRandom,
    protected_attribute,
    unpriviledged_num,
    privileged_num,
    "DisparateImpactRemover",
    False,
)
# Out:
#  Found a True value for the following preprocessing technique: DisparateImpactRemover
#  Adjusting the training data set accordingly.
# Base rate training set:  0.20522
# Disparate Impact training set: 1.853659073596853
# Mean-difference training set: 0.15578531574709256
# XGBoost algorithm succesfully recognized.
# Estimating the XGBoost model
# [13:50:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "max_features" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# .
# .

# %%
print("Confusion Matrix Report")
print(GB_outputDIWO[4])
# Out:
# Confusion Matrix Report
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.71      0.79    143060
#          1.0       0.36      0.63      0.46     36940
#
#     accuracy                           0.69    180000
#    macro avg       0.62      0.67      0.62    180000
# weighted avg       0.77      0.69      0.72    180000

# %%
dfM_GB_outputDIWO = GB_outputDIWO[7]
Performance_GB_outputDIWO = GB_outputDIWO[8]
auc_train_GB_outputDIWO, auc_test_GB_outputDIWO = GB_outputDIWO[9], GB_outputDIWO[10]

# %% [markdown]
# ### XGBoost Pre-processing: Reweighting

# %%
GB_outputRWWO = Estfun_ML(
    "XGBoost",
    df,
    iDepth,
    iRandom,
    protected_attribute,
    unpriviledged_num,
    privileged_num,
    "Reweighting",
    False,
)
# Out:
# XGBoost algorithm succesfully recognized.
# Estimating the XGBoost model
# training a weighted model
# [23:34:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "max_features" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# .
# .

# %%
print("Confusion Matrix Report")
print(GB_outputRWWO[4])
# Out:
# Confusion Matrix Report
#               precision    recall  f1-score   support
#
#            0       0.88      0.70      0.78    143060
#            1       0.35      0.63      0.45     36940
#
#     accuracy                           0.69    180000
#    macro avg       0.62      0.67      0.62    180000
# weighted avg       0.77      0.69      0.71    180000

# %%
dfM_GB_outputRWWO = GB_outputRWWO[7]
Performance_GB_outputRWWO = GB_outputRWWO[8]
auc_train_GB_outputRWWO, auc_test_GB_outputRWWO = GB_outputRWWO[9], GB_outputRWWO[10]

# %% [markdown]
# ### XGBoost Post-processing: Equalized Odds

# %%
GB_outputEOWO = Estfun_ML(
    "XGBoost",
    df,
    iDepth,
    iRandom,
    protected_attribute,
    unpriviledged_num,
    privileged_num,
    "EqualizedOds",
    False,
)
# Out:
# XGBoost algorithm succesfully recognized.
# Estimating the XGBoost model
# [13:50:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "max_features" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#  Found a True value for the following postprocessing technique: EqualizedOds
#  Adjusting the data set accordingly.
# .
# .
# .
# .

# %%
print("Confusion Matrix Report")
print(GB_outputEOWO[4])
# Out:
# Confusion Matrix Report
#               precision    recall  f1-score   support
#
#            0       0.85      0.75      0.80    143060
#            1       0.33      0.48      0.39     36940
#
#     accuracy                           0.70    180000
#    macro avg       0.59      0.62      0.59    180000
# weighted avg       0.74      0.70      0.71    180000

# %%
dfM_GB_outputEOWO = GB_outputEOWO[7]
Performance_GB_outputEOWO = GB_outputEOWO[8]
auc_train_GB_outputEOWO, auc_test_GB_outputEOWO = GB_outputEOWO[9], GB_outputEOWO[10]

# %% [markdown]
# ### XGBoost Post-processing: Reject Option Classification

# %%
GB_outputROCWO = Estfun_ML(
    "XGBoost",
    df,
    iDepth,
    iRandom,
    protected_attribute,
    unpriviledged_num,
    privileged_num,
    "RejectOptionClassification",
    False,
)
# Out:
# XGBoost algorithm succesfully recognized.
# Estimating the XGBoost model
# [13:51:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "max_features" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#  Found a True value for the following postprocessing technique: RejectOptionClassification
#  Adjusting the data set accordingly.
# .
# .
# Unable to satisy fairness constraints
# .
# .

# %%
print("Confusion Matrix Report")
print(GB_outputROCWO[4])
# Out:
# Confusion Matrix Report
#               precision    recall  f1-score   support
#
#            0       0.88      0.69      0.78    143060
#            1       0.35      0.65      0.46     36940
#
#     accuracy                           0.68    180000
#    macro avg       0.62      0.67      0.62    180000
# weighted avg       0.77      0.68      0.71    180000

# %%
dfM_GB_outputROCWO = GB_outputROCWO[7]
Performance_GB_outputROCWO = GB_outputROCWO[8]
auc_train_GB_outputROCWO, auc_test_GB_outputROCWO = (
    GB_outputROCWO[9],
    GB_outputROCWO[10],
)

# %% [markdown]
# # FINAL RESULTS: FAIRNESS METRICS

# %% [markdown]
# ## Logistic Regression

# %%
results_logistic_regression = (
    dfM_LogReg_output.merge(dfM_LogReg_outputWO, how="left", on=["Fairness Metrics"])
    .merge(dfM_LogReg_outputDIWO, how="left", on=["Fairness Metrics"])
    .merge(dfM_LogReg_outputRWWO, how="left", on=["Fairness Metrics"])
    .merge(dfM_LogReg_outputEOWO, how="left", on=["Fairness Metrics"])
    .merge(dfM_LogReg_outputROCWO, how="left", on=["Fairness Metrics"])
)

col = [
    "Fairness Metrics",
    "LR Starting value",
    "LR Unawareness",
    "Disparate Impact",
    "Reweighting",
    "Equalised Odds",
    "Reject Option Classification",
]

results_logistic_regression.columns = col

results_logistic_regression
# Out:
# Passing 'suffixes' which cause duplicate columns {'Values for Race_x'} in the result is deprecated and will raise a MergeError in a future version.
#                             Fairness Metrics  LR Starting value  \
# 0                                  Base_rate           0.427817
# 1                                Consistency           0.000000
# 2                           Disparate_impact           1.962553
# 3                            Mean_difference           0.360653
# 4                              Num_instances      180000.000000
# 5                              Num_negatives      102993.000000
# 6                              Num_positives       77007.000000
# 7   Smoothed_empirical_differential_fairness           4.929672
# 8                      AverageOddsDifference           0.297203
# 9                    AveragAbsOddsDifference           0.297203
# 10                EqualOpportunityDifference           0.252185
# 11                                 Errorrate           0.350061
# 12                            ErrorrateRatio           1.454253
# 13                        FalseDiscoveryRate           0.669277
# 14                       FalseDiscoveryRatio           0.854827
# 15                         FalseOmissionRate           0.111386
# 16                        FalseOmissionRatio           1.403703
#
#     LR Unawareness  Disparate Impact    Reweighting  Equalised Odds  \
# 0         0.419189          0.427050       0.411544        0.351978
# 1         0.000000          0.000000       0.000000        0.000000
# 2         1.328677          1.328144       1.326127        1.104364
# 3         0.128860          0.134306       0.125520        0.045594
# 4    180000.000000     180000.000000  180000.000000   180000.000000
# 5    104546.000000     103131.000000  105922.000000   116644.000000
# 6     75454.000000      76869.000000   74078.000000    63356.000000
# 7         4.419300          3.608141       3.919108        9.955981
# 8         0.079664          0.084237       0.076996        0.000033
# 9         0.079664          0.084237       0.076996        0.000158
# 10        0.079687          0.081932       0.079194       -0.000125
# 11        0.346956          0.351350       0.342278        0.345567
# 12        1.083480          1.076042       1.082248        0.976137
# 13        0.669057          0.671090       0.666514        0.699365
# 14        0.752572          0.757776       0.748200        0.731874
# 15        0.114485          0.113031       0.115519        0.153398
# 16        1.827755          1.818758       1.823202        2.026848
#
#     Reject Option Classification
# 0                       0.419189
# 1                       0.000000
# 2                       1.328677
# 3                       0.128860
# 4                  180000.000000
# 5                  104546.000000
# 6                   75454.000000
# 7                       4.419300
# 8                       0.079664
# 9                       0.079664
# 10                      0.079687
# 11                      0.346956
# 12                      1.083480
# 13                      0.669057
# 14                      0.752572
# 15                      0.114485
# 16                      1.827755

# %% [markdown]
# ## Random Forest

# %%
results_random_forest = (
    dfM_RandomForest_output.merge(
        dfM_RandomForest_outputWO, how="left", on=["Fairness Metrics"]
    )
    .merge(dfM_RandomForest_outputDIWO, how="left", on=["Fairness Metrics"])
    .merge(dfM_RandomForest_outputRWWO, how="left", on=["Fairness Metrics"])
    .merge(dfM_RandomForest_outputEOWO, how="left", on=["Fairness Metrics"])
    .merge(dfM_RandomForest_outputROCWO, how="left", on=["Fairness Metrics"])
)
results_random_forest

col = [
    "Fairness Metrics",
    "RF Starting value",
    "RF Unawareness",
    "Disparate Impact",
    "Reweighting",
    "Equalised Odds",
    "Reject Option Classification",
]

results_random_forest.columns = col

results_random_forest
# Out:
# Passing 'suffixes' which cause duplicate columns {'Values for Race_x'} in the result is deprecated and will raise a MergeError in a future version.
#                             Fairness Metrics  RF Starting value  \
# 0                                  Base_rate           0.353850
# 1                                Consistency           0.000000
# 2                           Disparate_impact           2.153436
# 3                            Mean_difference           0.341248
# 4                              Num_instances      180000.000000
# 5                              Num_negatives      116307.000000
# 6                              Num_positives       63693.000000
# 7   Smoothed_empirical_differential_fairness           2.771694
# 8                      AverageOddsDifference           0.283407
# 9                    AveragAbsOddsDifference           0.283407
# 10                EqualOpportunityDifference           0.254829
# 11                                 Errorrate           0.308417
# 12                            ErrorrateRatio           1.549887
# 13                        FalseDiscoveryRate           0.645817
# 14                       FalseDiscoveryRatio           0.864029
# 15                         FalseOmissionRate           0.123647
# 16                        FalseOmissionRatio           1.571032
#
#     RF Unawareness  Disparate Impact    Reweighting  Equalised Odds  \
# 0         0.370856          0.380578       0.371778        0.298806
# 1         0.000000          0.000000       0.000000        0.000000
# 2         1.325092          1.326714       1.327963        1.129086
# 3         0.112138          0.117460       0.113143        0.047766
# 4    180000.000000     180000.000000  180000.000000   180000.000000
# 5    113246.000000     111496.000000  113080.000000   126215.000000
# 6     66754.000000      68504.000000   66920.000000    53785.000000
# 7         2.927377          2.529576       2.660729        9.812090
# 8         0.064069          0.069212       0.065337       -0.000307
# 9         0.064069          0.069212       0.065337        0.000307
# 10        0.069466          0.075905       0.071500       -0.000590
# 11        0.318344          0.322544       0.318833        0.309372
# 12        1.105094          1.087770       1.103894        1.032278
# 13        0.652515          0.654137       0.652794        0.674277
# 14        0.734220          0.735365       0.733669        0.715441
# 15        0.121364          0.118811       0.121197        0.153872
# 16        1.852389          1.822553       1.844333        2.017926
#
#     Reject Option Classification
# 0                       0.372494
# 1                       0.000000
# 2                       1.323851
# 3                       0.112182
# 4                  180000.000000
# 5                  112951.000000
# 6                   67049.000000
# 7                       2.991166
# 8                       0.064244
# 9                       0.064244
# 10                      0.069783
# 11                      0.319583
# 12                      1.103135
# 13                      0.653507
# 14                      0.734308
# 15                      0.121362
# 16                      1.850578

# %% [markdown]
# ## Extreme Gradient Boosting

# %%
results_gradient_boosting = (
    dfM_GB_output.merge(dfM_GB_outputWO, how="left", on=["Fairness Metrics"])
    .merge(dfM_GB_outputDIWO, how="left", on=["Fairness Metrics"])
    .merge(dfM_GB_outputRWWO, how="left", on=["Fairness Metrics"])
    .merge(dfM_GB_outputEOWO, how="left", on=["Fairness Metrics"])
    .merge(dfM_GB_outputROCWO, how="left", on=["Fairness Metrics"])
)
results_gradient_boosting

col = [
    "Fairness Metrics",
    "GB Starting value",
    "GB Unawareness",
    "Disparate Impact",
    "Reweighting",
    "Equalised Odds",
    "Reject Option Classification",
]

results_gradient_boosting.columns = col

results_gradient_boosting
# Out:
# Passing 'suffixes' which cause duplicate columns {'Values for Race_x'} in the result is deprecated and will raise a MergeError in a future version.
#                             Fairness Metrics  GB Starting value  \
# 0                                  Base_rate           0.362700
# 1                                Consistency           0.000000
# 2                           Disparate_impact           2.224434
# 3                            Mean_difference           0.363465
# 4                              Num_instances      180000.000000
# 5                              Num_negatives      114714.000000
# 6                              Num_positives       65286.000000
# 7   Smoothed_empirical_differential_fairness           4.124342
# 8                      AverageOddsDifference           0.304932
# 9                    AveragAbsOddsDifference           0.304932
# 10                EqualOpportunityDifference           0.280660
# 11                                 Errorrate           0.305422
# 12                            ErrorrateRatio           1.560073
# 13                        FalseDiscoveryRate           0.638131
# 14                       FalseDiscoveryRatio           0.865547
# 15                         FalseOmissionRate           0.116071
# 16                        FalseOmissionRatio           1.390781
#
#     GB Unawareness  Disparate Impact    Reweighting  Equalised Odds  \
# 0         0.376117          0.359339       0.376117        0.296778
# 1         0.000000          0.000000       0.000000        0.000000
# 2         1.310509          1.349571       1.310509        1.136328
# 3         0.107872          0.117110       0.107872        0.050070
# 4    180000.000000     180000.000000  180000.000000   180000.000000
# 5    112299.000000     115319.000000  112299.000000   126580.000000
# 6     67701.000000      64681.000000   67701.000000    53420.000000
# 7         3.870802          3.573632       3.870802        9.811011
# 8         0.059341          0.069966       0.059341       -0.000834
# 9         0.059341          0.069966       0.059341        0.002665
# 10        0.068827          0.082318       0.068827       -0.003499
# 11        0.316206          0.306894       0.316206        0.304978
# 12        1.081107          1.098897       1.081107        1.038353
# 13        0.647538          0.641471       0.647538        0.668064
# 14        0.723315          0.723686       0.723315        0.715145
# 15        0.116457          0.119234       0.116457        0.151746
# 16        1.831104          1.793751       1.831104        2.041054
#
#     Reject Option Classification
# 0                       0.376117
# 1                       0.000000
# 2                       1.310509
# 3                       0.107872
# 4                  180000.000000
# 5                  112299.000000
# 6                   67701.000000
# 7                       3.870802
# 8                       0.059341
# 9                       0.059341
# 10                      0.068827
# 11                      0.316206
# 12                      1.081107
# 13                      0.647538
# 14                      0.723315
# 15                      0.116457
# 16                      1.831104

# %%
results_logistic_regression.to_csv(
    "./Reports/logistic_regression_fairness.csv", index=False
)
results_random_forest.to_csv("./Reports/random_forest.csv_fairness", index=False)
results_gradient_boosting.to_csv(
    "./Reports/gradient_boosting_fairness.csv", index=False
)

# %% [markdown]
# # FINAL RESULTS: PERFORMANCE METRICS

# %% [markdown]
# ## Logistic Regression

# %%
results_logistic_regression = (
    Performance_LogReg_output.merge(
        Performance_LogReg_outputWO, how="left", on=["Model Performance Metrics"]
    )
    .merge(Performance_LogReg_outputDIWO, how="left", on=["Model Performance Metrics"])
    .merge(Performance_LogReg_outputRWWO, how="left", on=["Model Performance Metrics"])
    .merge(Performance_LogReg_outputEOWO, how="left", on=["Model Performance Metrics"])
    .merge(Performance_LogReg_outputROCWO, how="left", on=["Model Performance Metrics"])
)

col = [
    "Fairness Metrics",
    "LR Starting value",
    "LR Unawareness",
    "Disparate Impact",
    "Reweighting",
    "Equalised Odds",
    "Reject Option Classification",
]

results_logistic_regression.columns = col

results_logistic_regression
# Out:
# Passing 'suffixes' which cause duplicate columns {'Values_x'} in the result is deprecated and will raise a MergeError in a future version.
#                    Fairness Metrics  LR Starting value  LR Unawareness  \
# 0                  accuracy_overall           0.649939        0.653044
# 1                  f1_score_overall           0.447015        0.444348
# 2                    f1_score_White           0.412119        0.411384
# 3                    accuracy_White           0.672578        0.661942
# 4         false_negative_rate_White           0.370353        0.351871
# 5         false_omission_rate_White           0.107952        0.105496
# 6          true_positive_rate_White           0.629647        0.648129
# 7   positive_predictive_value_White           0.306300        0.301319
# 8         false_positive_rate_White           0.317853        0.334979
# 9        false_discovery_rate_White           0.693700        0.698681
# 10               average_odds_White           0.473750        0.491554
# 11            prevelence_rate_White           0.182270        0.182270
# 12                   f1_score_Black           0.556953        0.574247
# 13                   accuracy_Black           0.523845        0.633721
# 14        false_negative_rate_Black           0.118168        0.272184
# 15        false_omission_rate_Black           0.151532        0.192820
# 16         true_positive_rate_Black           0.881832        0.727816
# 17  positive_predictive_value_Black           0.407006        0.474193
# 18        false_positive_rate_Black           0.660073        0.414620
# 19       false_discovery_rate_Black           0.592994        0.525807
# 20               average_odds_Black           0.770953        0.571218
# 21            prevelence_rate_Black           0.339392        0.339392
#
#     Disparate Impact  Reweighting  Equalised Odds  \
# 0           0.648650     0.653044        0.654311
# 1           0.444306     0.444348        0.379596
# 2           0.410424     0.411384        0.396827
# 3           0.651230     0.661942        0.626552
# 4           0.333979     0.351871        0.326022
# 5           0.103053     0.105496        0.105524
# 6           0.666021     0.648129        0.673978
# 7           0.296599     0.301319        0.281195
# 8           0.352067     0.334979        0.384019
# 9           0.703401     0.698681        0.718805
# 10          0.509044     0.491554        0.528999
# 11          0.182270     0.182270        0.182270
# 12          0.574977     0.574247        0.553230
# 13          0.624709     0.633721        0.632820
# 14          0.252047     0.272184        0.330162
# 15          0.187428     0.192820        0.216514
# 16          0.747953     0.727816        0.669838
# 17          0.466980     0.474193        0.471202
# 18          0.438608     0.414620        0.386198
# 19          0.533020     0.525807        0.528798
# 20          0.593281     0.571218        0.528018
# 21          0.339392     0.339392        0.339392
#
#     Reject Option Classification
# 0                       0.653044
# 1                       0.444348
# 2                       0.411384
# 3                       0.661942
# 4                       0.351871
# 5                       0.105496
# 6                       0.648129
# 7                       0.301319
# 8                       0.334979
# 9                       0.698681
# 10                      0.491554
# 11                      0.182270
# 12                      0.574247
# 13                      0.633721
# 14                      0.272184
# 15                      0.192820
# 16                      0.727816
# 17                      0.474193
# 18                      0.414620
# 19                      0.525807
# 20                      0.571218
# 21                      0.339392

# %% [markdown]
# ## Random Forest

# %%
results_random_forest = (
    Performance_RandomForest_output.merge(
        Performance_RandomForest_outputWO, how="left", on=["Model Performance Metrics"]
    )
    .merge(
        Performance_RandomForest_outputDIWO,
        how="left",
        on=["Model Performance Metrics"],
    )
    .merge(
        Performance_RandomForest_outputRWWO,
        how="left",
        on=["Model Performance Metrics"],
    )
    .merge(
        Performance_RandomForest_outputEOWO,
        how="left",
        on=["Model Performance Metrics"],
    )
    .merge(
        Performance_RandomForest_outputROCWO,
        how="left",
        on=["Model Performance Metrics"],
    )
)
results_random_forest

col = [
    "Fairness Metrics",
    "RF Starting value",
    "RF Unawareness",
    "Disparate Impact",
    "Reweighting",
    "Equalised Odds",
    "Reject Option Classification",
]

results_random_forest.columns = col

results_random_forest
# Out:
# Passing 'suffixes' which cause duplicate columns {'Values_x'} in the result is deprecated and will raise a MergeError in a future version.
#                    Fairness Metrics  RF Starting value  RF Unawareness  \
# 0                  accuracy_overall           0.691583        0.681656
# 1                  f1_score_overall           0.448342        0.447393
# 2                    f1_score_White           0.418662        0.417728
# 3                    accuracy_White           0.722049        0.693020
# 4         false_negative_rate_White           0.450890        0.395866
# 5         false_omission_rate_White           0.116714        0.110149
# 6          true_positive_rate_White           0.549110        0.604134
# 7   positive_predictive_value_White           0.338296        0.319229
# 8         false_positive_rate_White           0.239403        0.287167
# 9        false_discovery_rate_White           0.661704        0.680771
# 10               average_odds_White           0.394256        0.445651
# 11            prevelence_rate_White           0.182270        0.182270
# 12                   f1_score_Black           0.558837        0.574069
# 13                   accuracy_Black           0.569208        0.660759
# 14        false_negative_rate_Black           0.196061        0.326400
# 15        false_omission_rate_Black           0.183361        0.204039
# 16         true_positive_rate_Black           0.803939        0.673600
# 17  positive_predictive_value_Black           0.428268        0.500164
# 18        false_positive_rate_Black           0.551387        0.345839
# 19       false_discovery_rate_Black           0.571732        0.499836
# 20               average_odds_Black           0.677663        0.509720
# 21            prevelence_rate_Black           0.339392        0.339392
#
#     Disparate Impact  Reweighting  Equalised Odds  \
# 0           0.677456     0.681167        0.690628
# 1           0.449395     0.447429        0.386200
# 2           0.418384     0.417662        0.409059
# 3           0.684886     0.692959        0.673621
# 4           0.378184     0.395908        0.380247
# 5           0.107625     0.110169        0.110018
# 6           0.621816     0.604092        0.619753
# 7           0.315248     0.319165        0.305276
# 8           0.301056     0.287233        0.314372
# 9           0.684752     0.680835        0.694724
# 10          0.461436     0.445663        0.467062
# 11          0.182270     0.182270        0.182270
# 12          0.580129     0.575007        0.555049
# 13          0.657229     0.661059        0.663087
# 14          0.302279     0.324408        0.380836
# 15          0.196152     0.203188        0.222007
# 16          0.697721     0.675592        0.619164
# 17          0.496457     0.500492        0.502966
# 18          0.363574     0.346407        0.314347
# 19          0.503543     0.499508        0.497034
# 20          0.530648     0.511000        0.466755
# 21          0.339392     0.339392        0.339392
#
#     Reject Option Classification
# 0                       0.680417
# 1                       0.446816
# 2                       0.417273
# 3                       0.691931
# 4                       0.394855
# 5                       0.110113
# 6                       0.605145
# 7                       0.318417
# 8                       0.288725
# 9                       0.681583
# 10                      0.446935
# 11                      0.182270
# 12                      0.574118
# 13                      0.660158
# 14                      0.325072
# 15                      0.203773
# 16                      0.674928
# 17                      0.499509
# 18                      0.347431
# 19                      0.500491
# 20                      0.511179
# 21                      0.339392

# %% [markdown]
# ## Extreme Gradient Boosting

# %%
results_gradient_boosting = (
    Performance_GB_output.merge(
        Performance_GB_outputWO, how="left", on=["Model Performance Metrics"]
    )
    .merge(Performance_GB_outputDIWO, how="left", on=["Model Performance Metrics"])
    .merge(Performance_GB_outputRWWO, how="left", on=["Model Performance Metrics"])
    .merge(Performance_GB_outputEOWO, how="left", on=["Model Performance Metrics"])
    .merge(Performance_GB_outputROCWO, how="left", on=["Model Performance Metrics"])
)
results_gradient_boosting

col = [
    "Fairness Metrics",
    "GB Starting value",
    "GB Unawareness",
    "Disparate Impact",
    "Reweighting",
    "Equalised Odds",
    "Reject Option Classification",
]

results_gradient_boosting.columns = col

results_gradient_boosting
# Out:
# Passing 'suffixes' which cause duplicate columns {'Values_x'} in the result is deprecated and will raise a MergeError in a future version.
#                    Fairness Metrics  GB Starting value  GB Unawareness  \
# 0                  accuracy_overall           0.694578        0.683794
# 1                  f1_score_overall           0.462211        0.456074
# 2                    f1_score_White           0.426766        0.423840
# 3                    accuracy_White           0.725356        0.694823
# 4         false_negative_rate_White           0.439102        0.384162
# 5         false_omission_rate_White           0.113822        0.107296
# 6          true_positive_rate_White           0.560898        0.615838
# 7   positive_predictive_value_White           0.344406        0.323106
# 8         false_positive_rate_White           0.237986        0.287571
# 9        false_discovery_rate_White           0.655594        0.676894
# 10               average_odds_White           0.399442        0.451704
# 11            prevelence_rate_White           0.182270        0.182270
# 12                   f1_score_Black           0.571407        0.584822
# 13                   accuracy_Black           0.571536        0.670071
# 14        false_negative_rate_Black           0.158442        0.315335
# 15        false_omission_rate_Black           0.158302        0.196470
# 16         true_positive_rate_Black           0.841558        0.684665
# 17  positive_predictive_value_Black           0.432552        0.510393
# 18        false_positive_rate_Black           0.567190        0.337426
# 19       false_discovery_rate_Black           0.567448        0.489607
# 20               average_odds_Black           0.704374        0.511045
# 21            prevelence_rate_Black           0.339392        0.339392
#
#     Disparate Impact  Reweighting  Equalised Odds  \
# 0           0.693106     0.683794        0.695022
# 1           0.456402     0.456074        0.392475
# 2           0.423551     0.423840        0.416415
# 3           0.701814     0.694823        0.679292
# 4           0.398981     0.384162        0.372248
# 5           0.109358     0.107296        0.107234
# 6           0.601019     0.615838        0.627752
# 7           0.326996     0.323106        0.311535
# 8           0.275719     0.287571        0.309220
# 9           0.673004     0.676894        0.688465
# 10          0.438369     0.451704        0.468486
# 11          0.182270     0.182270        0.182270
# 12          0.586014     0.584822        0.559944
# 13          0.672324     0.670071        0.666992
# 14          0.316663     0.315335        0.375747
# 15          0.196162     0.196470        0.218871
# 16          0.683337     0.684665        0.624253
# 17          0.512957     0.510393        0.507648
# 18          0.333333     0.337426        0.311050
# 19          0.487043     0.489607        0.492352
# 20          0.508335     0.511045        0.467652
# 21          0.339392     0.339392        0.339392
#
#     Reject Option Classification
# 0                       0.683794
# 1                       0.456074
# 2                       0.423840
# 3                       0.694823
# 4                       0.384162
# 5                       0.107296
# 6                       0.615838
# 7                       0.323106
# 8                       0.287571
# 9                       0.676894
# 10                      0.451704
# 11                      0.182270
# 12                      0.584822
# 13                      0.670071
# 14                      0.315335
# 15                      0.196470
# 16                      0.684665
# 17                      0.510393
# 18                      0.337426
# 19                      0.489607
# 20                      0.511045
# 21                      0.339392

# %%
results_logistic_regression.to_csv(
    "./Reports/logistic_regression_performance.csv", index=False
)
results_random_forest.to_csv("./Reports/random_forest_performance.csv", index=False)
results_gradient_boosting.to_csv(
    "./Reports/gradient_boosting_performance.csv", index=False
)

# %% [markdown]
# # AUC values: All models

# %%
AUC_models = dict(
    Model=[
        "Logistic Regression Initial",
        "Logisctic Regrssion Unawareness",
        "LR Disparate Impact",
        "LR Reweighting",
        "LR Equalised Odds",
        "LR Reject Option Classification",
        "Random Forest Initial",
        "Random Forest Unawareness",
        "RF Disparate Impact",
        "RF Reweighting",
        "RF Equalised Odds",
        "RF Reject Option Classification",
        "Gradient Boosting Initial",
        "Gradient Boosting Unawareness",
        "GB Disparate Impact",
        "GB Reweighting",
        "GB Equalised Odds",
        "GB Reject Option Classification",
    ],
    AUC_train=[
        auc_train_LogReg_output,
        auc_train_LogReg_outputWO,
        auc_train_LogReg_outputDIWO,
        auc_train_LogReg_outputRWWO,
        auc_train_LogReg_outputEOWO,
        auc_train_LogReg_outputROCWO,
        auc_train_RandomForest_output,
        auc_train_RandomForest_outputWO,
        auc_train_RandomForest_outputDIWO,
        auc_train_RandomForest_outputRWWO,
        auc_train_RandomForest_outputEOWO,
        auc_train_RandomForest_outputROCWO,
        auc_train_GB_output,
        auc_train_GB_outputWO,
        auc_train_GB_outputDIWO,
        auc_train_GB_outputRWWO,
        auc_train_GB_outputEOWO,
        auc_train_GB_outputROCWO,
    ],
    AUC_test=[
        auc_test_LogReg_output,
        auc_test_LogReg_outputWO,
        auc_test_LogReg_outputDIWO,
        auc_test_LogReg_outputRWWO,
        auc_test_LogReg_outputEOWO,
        auc_test_LogReg_outputROCWO,
        auc_test_RandomForest_output,
        auc_test_RandomForest_outputWO,
        auc_test_RandomForest_outputDIWO,
        auc_test_RandomForest_outputRWWO,
        auc_test_RandomForest_outputEOWO,
        auc_test_RandomForest_outputROCWO,
        auc_test_GB_output,
        auc_test_GB_outputWO,
        auc_test_GB_outputDIWO,
        auc_test_GB_outputRWWO,
        auc_test_GB_outputEOWO,
        auc_test_GB_outputROCWO,
    ],
)

# %%
auc_df = pd.DataFrame(AUC_models)
auc_df
# Out:
#                               Model  AUC_train  AUC_test
# 0       Logistic Regression Initial   0.663932  0.664594
# 1   Logisctic Regrssion Unawareness   0.662087  0.661558
# 2               LR Disparate Impact   0.660847  0.661926
# 3                    LR Reweighting   0.662087  0.661558
# 4                 LR Equalised Odds   0.662087  0.661558
# 5   LR Reject Option Classification   0.662087  0.661558
# 6             Random Forest Initial   0.704230  0.661562
# 7         Random Forest Unawareness   0.686550  0.661894
# 8               RF Disparate Impact   0.678432  0.664133
# 9                    RF Reweighting   0.686534  0.661823
# 10                RF Equalised Odds   0.686524  0.661880
# 11  RF Reject Option Classification   0.686539  0.661369
# 12        Gradient Boosting Initial   0.680380  0.674041
# 13    Gradient Boosting Unawareness   0.675357  0.669792
# 14              GB Disparate Impact   0.672899  0.668860
# 15                   GB Reweighting   0.675357  0.669792
# 16                GB Equalised Odds   0.675357  0.669792
# 17  GB Reject Option Classification   0.675357  0.669792

# %%
auc_df.to_csv("./Reports/auc_results.csv", index=False)
